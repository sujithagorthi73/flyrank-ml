# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sujithagorthi73/flyrank-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ### My Lane
#
# I chose **Lane 4: CTR / Engagement Opportunity Scoring** because it focuses on identifying pages that receive fewer clicks than expected despite being visible in search results. This can help identify opportunities to improve page titles, metadata, or content so users are more likely to click.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### Research Question
#
# **Question:** Which pages receive lower CTR than expected for their search position?
#
# **Decision:** Decide which pages should be optimized first.
#
# **Action:** Improve page titles, meta descriptions, or content for those pages.
#
# **Cost of a wrong recommendation:** Time and effort could be wasted optimizing pages that do not actually need improvements, while better opportunities are missed.
#
# **Why ML helps:** Machine learning can analyze many pages at once and identify patterns that are difficult to find manually, helping prioritize optimization opportunities.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ### Quick look at the data
#
# From the starter notebook, I observed:
#
# - Pages in the top position tier had the highest average CTR (around 0.35), while deeper positions had much lower CTR (around 0.06).
# - CTR consistently decreased as search position became lower.
# - Pages with growing and declining trends had similar median word counts, suggesting that content length alone does not explain page performance.
#
# These observations support my choice of studying CTR opportunities because search position and CTR appear to be strongly related.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ### Careful words
#
# This work identifies patterns in the available data and provides decision support. It does not prove how search engines rank pages or guarantee that improving a page will increase its ranking or CTR. Any recommendations should be validated before being applied.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
